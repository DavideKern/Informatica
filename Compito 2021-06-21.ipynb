# %%
import numpy as np
import matplotlib.pyplot as plt
M=10**4

def f(x):
    return 4/np.pi**4 * (x**2 - np.pi**2) * (x**2 - (np.pi/2)**2)

def fk(x,k):
    return f(x) * np.cos(k*x)

def I(k):
    A=0
    dx=2*np.pi/M
    for i in range(M):
        dA= dx/2 * (fk(-np.pi+i*dx,k) + fk(-np.pi+(i+1)*dx,k))
        A+=dA
    return A

C=[]
for k in range(10):
    C.append( round(I(k)/np.pi,7) )

for N in range(0,10):
    def S(x,N):
        S=C[0]/2
        k=1
        while k<=N:
            S+= C[k]*np.cos(k*x)
            k+=1
        return S

X=np.linspace(-np.pi, np.pi, M)
Y=np.zeros((10,M))
for N in range(10):
    Y[N]=S(X,N)

def d(x,N):
    return (f(x) - S(x,N))**2

def dist(N):
    A=0
    dx = 2*np.pi/M
    for i in range(M):
        dA= dx/2 * (d(-np.pi + i*dx, N) + d(-np.pi + (i+1)*dx, N))
        A+=dA
    return A

D=[]
for k in range(10):
    D.append( round(dist(k),7) )

# %%
print('La sequenza {c_k} per k = 0, ..., 9 è:')
print(tuple(C),'\n\n')

print('Segue il confronto tra i grafici di f (rosso) e di S_0 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[0],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_1 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[1],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_2 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[2],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_3 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[3],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_4 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[4],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_5 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[5],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_6 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[6],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_7 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[7],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_8 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[8],'blue')
plt.show()

print('Segue il confronto tra i grafici di f (rosso) e di S_9 (blu):')
z=plt.plot(X,f(X),'red')
z=plt.plot(X,Y[9],'blue')
plt.show()

print('\nLa sequenza delle distanze quadratiche di S_N rispetto f (per N = 0, ..., 9) è:')
print(tuple(D))
# Out:
# La sequenza {c_k} per k = 0, ..., 9 è:
# (0.2666667, 0.7552143, 0.1807718, -0.1107608, 0.0682914, -0.0454805, 0.0322529, -0.0239925, 0.0185165, -0.0147102)
#
#
# Segue il confronto tra i grafici di f (rosso) e di S_0 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_1 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_2 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_3 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_4 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_5 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_6 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_7 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_8 (blu):
# Segue il confronto tra i grafici di f (rosso) e di S_9 (blu):
# La sequenza delle distanze quadratiche di S_N rispetto f (per N = 0, ..., 9) è:
# (1.9627474, 0.170944, 0.0682817, 0.0297408, 0.0150893, 0.008591, 0.0053229, 0.0035145, 0.0024374, 0.0017576)
